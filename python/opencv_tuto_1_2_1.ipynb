# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
print (cv2.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1fc0476879a1> in <module>
# ----> 1 print (cv2.__version__)
#
# NameError: name 'cv2' is not defined

# %%
import cv2

# %%
print (cv2.__version__)
# Out:
# 4.4.0

# %%
import numpy as np

# %%
img = cv2.imread("test.jpg", 0)

# %%
print (img)
# Out:
# [[233 233 233 ... 234 238 238]
#  [233 233 233 ... 234 234 234]
#  [233 233 233 ... 234 231 231]
#  ...
#  [123 118 124 ... 120 124 123]
#  [134 135 132 ...  95 106 108]
#  [134 135 132 ...  95 106 108]]

# %%
cv2.imshow ('imgae', img)
cv2.waitKey (0)
cv2.destroyAllWindows ()

# %%
cv2.imwrite ('test.png',img)
# Out:
# True

# %%
cv2.imshow ('image', img)
k = cv2.waitKey(0)
if (k==27) :
    cv2.destroyAllWindows()
elif (k == ord('s')) :
    cv2.imwrite ('test.png', img)
    cv2.destroyAllWindows ()
else :
    cv2.imwrite ('else.png', img)
    cv2.destroyAllWindows ()

# %%
from matplotlib import pyplot as plt

# %%
img = cv2.imread ('test.jpg', 0)
plt.imshow (img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])    # to hide tick values on X
plt.show()

# %%
img = cv2.imread ('test.jpg')
b,g,r = cv2.split(img)
img2 = cv2.merge([r,g,b])
plt.subplot(121); plt.imshow(img)
plt.subplot(122); plt.imshow(img2)
plt.show()
print (r)
print (g)
print (b)
# Out:
# [[237 237 236 ... 231 235 235]
#  [237 237 236 ... 231 231 231]
#  [236 236 236 ... 233 230 230]
#  ...
#  [126 119 123 ... 124 125 123]
#  [137 136 131 ...  99 107 108]
#  [137 136 131 ...  99 107 108]]
# [[234 234 234 ... 239 243 243]
#  [234 234 234 ... 239 239 239]
#  [235 235 235 ... 238 235 235]
#  ...
#  [124 120 127 ... 119 125 125]
#  [135 137 135 ...  94 107 110]
#  [135 137 135 ...  94 107 110]]
# [[219 219 219 ... 215 220 220]
#  [219 217 219 ... 215 216 216]
#  [217 215 217 ... 215 212 212]
#  ...
#  [109 106 113 ... 113 115 114]
#  [120 123 121 ...  88  97  99]
#  [120 123 121 ...  88  97  99]]

# %%
cv2.imshow ('bgr image', img)
cv2.imshow ('rgb image', img2)
cv2.waitKey (0)
cv2.destroyAllWindows ()
